# %%
import numpy as np
import pandas as pd
from pandas import json_normalize

import warnings
warnings.filterwarnings("ignore")

import folium
from folium import Marker, Icon, Map
from folium.plugins import HeatMap

# %% [markdown]
# # **Merge to get the ``coordinates``**

# %%
df_exploded = pd.read_csv('Datasets/df_exploded.csv')
df_exploded.shape
# Out:
# (14658, 14)

# %%
df_artists_origins_coordinates = pd.read_csv('Datasets/df_artists_origins_coordinates.csv')
df_artists_origins_coordinates.shape
# Out:
# (4888, 6)

# %%
df_exploded['artist'].nunique() # there are less probably because in artists_origins there are artists from other countries (not just the UK and US) and styles that I dropped
# Out:
# 3392

# %%
df_artists_origins_coordinates.head(1)
# Out:
#    artist        country     city   latitude  longitude  \
# 0  Sparta  United States  El Paso  31.760116 -106.48704
#
#                                          address
# 0  El Paso, El Paso County, Texas, United States

# %%
df = pd.merge(df_exploded, df_artists_origins_coordinates, on='artist')
df.head()
# Out:
#    artist_id  master_id  main_release_id release_country             artist  \
# 0   15152368    3747909         31909420             NaN   As Living Arrows
# 1    2190314    3731373         32952558              US     Just Surrender
# 2    2190314    3731373         32952558              US     Just Surrender
# 3    7333323    3685869         32557566              UK     Hidden Mothers
# 4    3398500    3682731         32371239              US  Tiny Moving Parts
#
#                 title  year  album_length  tracks  \
# 0       Hope and Ruin  2024          0.00       8
# 1             Phoenix  2010          0.00      13
# 2             Phoenix  2010          0.00      13
# 3  Erosion / Avulsion  2024         41.47       8
# 4    Deep in the Blue  2024          0.00      10
#
#                          release_type    genres subgenre             style  \
# 0                     ['LP', 'Album']  ['Rock']     punk     Post-Hardcore
# 1                           ['Album']  ['Rock']    indie  Alternative Rock
# 2                           ['Album']  ['Rock']     punk          Pop Punk
# 3                              ['LP']  ['Rock']     punk     Post-Hardcore
# 4  ['LP', 'Album', 'Limited Edition']  ['Rock']    indie               Emo
#
#                                       artist_profile         country  \
# 0           Post-screamo band from Brighton, UK\r\n   United Kingdom
# 1  Band from Dover Plains, New York, formerly kno...   United States
# 2  Band from Dover Plains, New York, formerly kno...   United States
# 3  Post-black metal band from Sheffield, UK\r\n\r...  United Kingdom
# 4  Trio from Benson, Minnesota. The band takes in...   United States
#
#            city   latitude  longitude  \
# 0      Brighton  50.821463  -0.140056
# 1  Dover Plains  41.738426 -73.570886
# 2  Dover Plains  41.738426 -73.570886
# 3     Sheffield  53.380663  -1.470228
# 4        Benson  45.314960 -95.600035
#
#                                              address
# 0  Brighton, Brighton and Hove, England, BN1 1HH,...
# 1  Dover Plains, Bains Corner, Dover Plains, Town...
# 2  Dover Plains, Bains Corner, Dover Plains, Town...
# 3  Sheffield, South Yorkshire, England, United Ki...
# 4     Benson, Swift County, Minnesota, United States

# %%
df_uk = df[df['country']=='United Kingdom']
df_uk.shape
# Out:
# (5881, 19)

# %%
df_us = df[df['country']=='United States']
df_us.shape
# Out:
# (8777, 19)

# %% [markdown]
# # **UK map**

# %%
# create the map
us_lat = 38.09612098863635 
us_lon = -96.48185032372986 
map_us = Map(location=[us_lat, us_lon], zoom_start=5)

# %% [markdown]
# ## Create the layers

# %%
# create the subset of the subgenre
uk_indie = df_uk[df_uk['subgenre']=='indie']

# create the FeatureGroup
uk_indie_group = folium.FeatureGroup(name = f'uk_indie: {uk_indie.shape[0]}') 

# the subset is the subgenre and we i només ens interessen 2 columnes: les coordenades
HeatMap(data = uk_indie[['latitude', 'longitude']]).add_to(uk_indie_group) 
uk_indie_group.add_to(map_uk)

# %%
# create the subset of the subgenre
uk_metal = df_uk[df_uk['subgenre']=='metal']

# create the FeatureGroup
uk_metal_group = folium.FeatureGroup(name = f'uk_metal: {uk_metal.shape[0]}') 

# the subset is the subgenre and we i només ens interessen 2 columnes: les coordenades
HeatMap(data = uk_metal[['latitude', 'longitude']]).add_to(uk_metal_group) 
uk_metal_group.add_to(map_uk)

# %%
# create the subset of the subgenre
uk_classic = df_uk[df_uk['subgenre']=='classic']

# create the FeatureGroup
uk_classic_group = folium.FeatureGroup(name = f'uk_classic: {uk_classic.shape[0]}') 

# the subset is the subgenre and we i només ens interessen 2 columnes: les coordenades
HeatMap(data = uk_classic[['latitude', 'longitude']]).add_to(uk_classic_group) 
uk_classic_group.add_to(map_uk)

# %%
# create the subset of the subgenre
uk_punk = df_uk[df_uk['subgenre']=='punk']

# create the FeatureGroup
uk_punk_group = folium.FeatureGroup(name = f'uk_punk: {uk_punk.shape[0]}') 

# the subset is the subgenre and we i només ens interessen 2 columnes: les coordenades
HeatMap(data = uk_punk[['latitude', 'longitude']]).add_to(uk_punk_group) 
uk_punk_group.add_to(map_uk)

# %%
# create the subset of the subgenre
uk_roots = df_uk[df_uk['subgenre']=='roots']

# create the FeatureGroup
uk_roots_group = folium.FeatureGroup(name = f'uk_roots: {uk_roots.shape[0]}') 

# the subset is the subgenre and we i només ens interessen 2 columnes: les coordenades
HeatMap(data = uk_roots[['latitude', 'longitude']]).add_to(uk_roots_group) 
uk_roots_group.add_to(map_uk)

# %% [markdown]
# ## Adding The Layer Control

# %%
folium.LayerControl(collapsed=False, position="topleft").add_to(map_uk)
map_uk
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_214b862c6059c4cec8163b21d4488a07 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_214b862c6059c4cec8163b21d4488a07&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_214b862c6059c4cec8163b21d4488a07 = L.map(
#                 &quot;map_214b862c6059c4cec8163b21d4488a07&quot;,
#                 {
#                     center: [53.96973040762258, -2.5503993478335634],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b82ece9722be03584537c37e15a61ea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3b82ece9722be03584537c37e15a61ea.addTo(map_214b862c6059c4cec8163b21d4488a07);
#
#
#             var feature_group_e078f5e09b58249aee106e17098fe872 = L.featureGroup(
#                 {}
#             );
#
#
#             var heat_map_533d924070f3a21497c643d8e5f471f9 = L.heatLayer(
#                 [[51.1103444, -0.1801094], [50.8214626, -0.1400561], [51.5074456, -0.1277653], [51.4893335, -0.1440550845276872], [53.3806626, -1.4702278], [51.4893335, -0.1440550845276872], [53.84036055, -3.016109110103628], [50.4134414, -5.0848836], [51.4893335, -0.1440550845276872], [51.4893335, -0.1440550845276872], [51.4893335, -0.1440550845276872], [51.4816546, -3.1791934], [53.4794892, -2.2451148], [52.4796992, -1.9026911], [52.4796992, -1.9026911], [52.4796992, -1.9026911], [50.7256138, -3.5269209], [50.7256138, -3.5269209], [50.9774051, -1.1281535], [53.7974185, -1.5437941], [51.7520131, -1.2578499], [51.7520131, -1.2578499], [53.8179442, -3.0509812], [53.8179442, -3.0509812], [53.5927543, -2.2972827], [55.9533456, -3
map_us = Map(location=[us_lat, us_lon], zoom_start=5)

# %% [markdown]
# ## Create the layers

# %%
# create the subset of the subgenre
us_indie = df_us[df_us['subgenre']=='indie']

# create the FeatureGroup
us_indie_group = folium.FeatureGroup(name = f'us_indie: {us_indie.shape[0]}') 

# the subset is the subgenre and we i només ens interessen 2 columnes: les coordenades
HeatMap(data = us_indie[['latitude', 'longitude']]).add_to(us_indie_group) 
us_indie_group.add_to(map_us)

# %%
# create the subset of the subgenre
us_metal = df_us[df_us['subgenre']=='metal']

# create the FeatureGroup
us_metal_group = folium.FeatureGroup(name = f'us_metal: {us_metal.shape[0]}') 

# the subset is the subgenre and we i només ens interessen 2 columnes: les coordenades
HeatMap(data = us_metal[['latitude', 'longitude']]).add_to(us_metal_group) 
us_metal_group.add_to(map_us)

# %%
# create the subset of the subgenre
us_classic = df_us[df_us['subgenre']=='classic']

# create the FeatureGroup
uk_classic_group = folium.FeatureGroup(name = f'uk_classic: {uk_classic.shape[0]}') 

# the subset is the subgenre and we i només ens interessen 2 columnes: les coordenades
HeatMap(data = uk_classic[['latitude', 'longitude']]).add_to(uk_classic_group) 
uk_classic_group.add_to(map_us)

# %%
# create the subset of the subgenre
us_punk = df_us[df_us['subgenre']=='punk']

# create the FeatureGroup
uk_punk_group = folium.FeatureGroup(name = f'uk_punk: {uk_punk.shape[0]}') 

# the subset is the subgenre and we i només ens interessen 2 columnes: les coordenades
HeatMap(data = uk_punk[['latitude', 'longitude']]).add_to(uk_punk_group) 
uk_punk_group.add_to(map_us)

# %%
# create the subset of the subgenre
us_roots = df_us[df_us['subgenre']=='roots']

# create the FeatureGroup
us_roots_group = folium.FeatureGroup(name = f'us_roots: {us_roots.shape[0]}') 

# the subset is the subgenre and we i només ens interessen 2 columnes: les coordenades
HeatMap(data = us_roots[['latitude', 'longitude']]).add_to(us_roots_group) 
us_roots_group.add_to(map_us)

# %% [markdown]
# ## Adding The Layer Control

# %%
folium.LayerControl(collapsed=False, position="topleft").add_to(map_us)
map_us
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_222b7fe17101bc0d6b7d19fbf70d32b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_222b7fe17101bc0d6b7d19fbf70d32b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_222b7fe17101bc0d6b7d19fbf70d32b6 = L.map(
#                 &quot;map_222b7fe17101bc0d6b7d19fbf70d32b6&quot;,
#                 {
#                     center: [38.09612098863635, -96.48185032372986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e45c0a4f291ecd331362db9931516511 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e45c0a4f291ecd331362db9931516511.addTo(map_222b7fe17101bc0d6b7d19fbf70d32b6);
#
#
#             var feature_group_c3af888dc6dfc13493791dac3d02b677 = L.featureGroup(
#                 {}
#             );
#
#
#             var heat_map_dccdd1b74ebec287fd004ed05c0e4a4c = L.heatLayer(
#                 [[41.7384257, -73.57088619574469], [45.3149604, -95.6000349], [39.0817985, -77.1516844], [34.0536909, -118.242766], [34.1481692, -118.7655456], [40.5885508, -73.6582631], [40.5885508, -73.6582631], [40.518157, -74.4113926], [40.518157, -74.4113926], [42.3554334, -71.060511], [42.3554334, -71.060511], [38.8950368, -77.0365427], [38.8950368, -77.0365427], [38.6280278, -90.1910154], [38.6280278, -90.1910154], [35.595363, -82.5508407], [25.7741728, -80.19362], [38.4404925, -122.7141049], [47.6038321, -122.330062], [40.8466508, -73.8785937], [39.27573585